# %% [markdown]
# #  Data Wrangling with Python: Activity05

# %%
#Import general python packages

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Read the 'Boston_housing.csv' file

# %%
#Read "Boston_housing.csv" file 
df=pd.read_csv("Boston_housing.csv")
df.head()

#This function selects the min in each column and highlights it in limegreen color
def highlight_min(s):    
    is_min = s == s.min()
    return ['background-color: limegreen' if v else '' for v in is_min]
 
#apply the previously defined function on dataframe
df.style.apply(highlight_min)
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# # Identify Variables

# %%
#Identify variables and it's attributes in the dataset
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  PRICE    506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# ...

# %% [markdown]
# # Check the first 10 records and find the total number of records

# %%
# 10 first records
df.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222     18.7
# 5  0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222     18.7
# 6  0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311     15.2
# 7  0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311     15.2
# 8  0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311     15.2
# 9  0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311     15.2
#
#         B  LSTAT  PRICE
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# ...

# %%
#Total numbe of records 
df.shape
# Out:
# (506, 14)

# %% [markdown]
# # Create a smaller DataFrame with columns which do not include 'CHAS', 'NOX', 'B', and 'LSTAT'

# %%
#Create new data frame and show the total numbere of records
df1=df[['CRIM','ZN','INDUS','RM','AGE','DIS','RAD','TAX','PTRATIO','PRICE']]
df1
# Out:
#         CRIM    ZN  INDUS     RM   AGE     DIS  RAD  TAX  PTRATIO  PRICE
# 0    0.00632  18.0   2.31  6.575  65.2  4.0900    1  296     15.3   24.0
# 1    0.02731   0.0   7.07  6.421  78.9  4.9671    2  242     17.8   21.6
# 2    0.02729   0.0   7.07  7.185  61.1  4.9671    2  242     17.8   34.7
# 3    0.03237   0.0   2.18  6.998  45.8  6.0622    3  222     18.7   33.4
# 4    0.06905   0.0   2.18  7.147  54.2  6.0622    3  222     18.7   36.2
# ..       ...   ...    ...    ...   ...     ...  ...  ...      ...    ...
# 501  0.06263   0.0  11.93  6.593  69.1  2.4786    1  273     21.0   22.4
# 502  0.04527   0.0  11.93  6.120  76.7  2.2875    1  273     21.0   20.6
# 503  0.06076   0.0  11.93  6.976  91.0  2.1675    1  273     21.0   23.9
# 504  0.10959   0.0  11.93  6.794  89.3  2.3889    1  273     21.0   22.0
# 505  0.04741   0.0  11.93  6.030  80.8  2.5050    1  273     21.0   11.9
#
# [506 rows x 10 columns]

# %% [markdown]
# # Check the last 7 records of the new DataFrame

# %%
#Last 7 DataFrame 
df1.tail(7)
# Out:
#         CRIM   ZN  INDUS     RM   AGE     DIS  RAD  TAX  PTRATIO  PRICE
# 499  0.17783  0.0   9.69  5.569  73.5  2.3999    6  391     19.2   17.5
# 500  0.22438  0.0   9.69  6.027  79.7  2.4982    6  391     19.2   16.8
# 501  0.06263  0.0  11.93  6.593  69.1  2.4786    1  273     21.0   22.4
# 502  0.04527  0.0  11.93  6.120  76.7  2.2875    1  273     21.0   20.6
# 503  0.06076  0.0  11.93  6.976  91.0  2.1675    1  273     21.0   23.9
# 504  0.10959  0.0  11.93  6.794  89.3  2.3889    1  273     21.0   22.0
# 505  0.04741  0.0  11.93  6.030  80.8  2.5050    1  273     21.0   11.9

# %% [markdown]
# # Plot the histograms of all the variables (columns)in the new DataFrame

# %%
#Draw histograms of all variables in the new DataFrame.
# I will plot them one by one 
plt.figure(figsize=(8,4))
plt.hist(df['CRIM'], color = 'blue', bins=20)
plt.title('Plot of CRIM', fontsize=17)

plt.figure(figsize=(8,4))
plt.hist(df['ZN'], color = 'blue', bins=20)
plt.title('Plot of ZN', fontsize=17)

plt.figure(figsize=(8,4))
plt.hist(df['INDUS'], color = 'blue', bins=20)
plt.title('Plot of INDUS', fontsize=17)

plt.figure(figsize=(8,4))
plt.hist(df['RM'], color = 'blue', bins=20)
plt.title('Plot of RM', fontsize=17)

plt.figure(figsize=(8,4))
plt.hist(df['AGE'], color = 'blue', bins=20)
plt.title('Plot of AGE', fontsize=17)

plt.figure(figsize=(8,4))
plt.hist(df['DIS'], color = 'blue', bins=20)
plt.title('Plot of DIS', fontsize=17)

plt.figure(figsize=(8,4))
plt.hist(df['RAD'], color = 'blue', bins=20)
plt.title('Plot of RAD', fontsize=17)

plt.figure(figsize=(8,4))
plt.hist(df['TAX'], color = 'blue', bins=20)
plt.title('Plot of TAX', fontsize=17)

plt.figure(figsize=(8,4))
plt.hist(df['PTRATIO'], color = 'blue', bins=20)
plt.title('Plot of PTRATIO', fontsize=17)

plt.figure(figsize=(8,4))
plt.hist(df['PRICE'], color = 'blue', bins=20)
plt.title('Plot of PRICE', fontsize=17)
# Out:
# Text(0.5, 1.0, 'Plot of PRICE')

# %%
# here's the author code ,which write a short code to plot all of them once and used 'fol loop'
# I did not know how to use 'for loop' for multi variables to get the plot at one, so I just pasted from author.
for c in df1.columns:
    plt.title("Plot of "+c,fontsize=15)
    plt.hist(df1[c],bins=20)
    plt.show()

# %% [markdown]
# # Create a scatter plot of crime rate vs. Price.

# %%
#Rate vs. Price
plt.scatter(df1['CRIM'], df['PRICE'])
plt.xlabel("CRIM")
plt.ylabel("PRICE")
plt.title("Rate vs. Price")
# Out:
# Text(0.5, 1.0, 'Rate vs. Price')

# %% [markdown]
# # Plot using log10(crime) vs. price

# %%
# Plot log10(crime) vs. Price to get better undreastading relationship
plt.scatter(np.log10(df1['CRIM']),df1['PRICE'],c='red')
plt.title("Crime rate (Log) vs. Price plot", fontsize=18)
plt.xlabel("Log of Crime rate",fontsize=15)
plt.ylabel("Price",fontsize=15)
plt.grid(True)
plt.show()

# %% [markdown]
# #  calculate mean rooms per dwelling

# %%
#calculate the mean of 'RM'
df1['RM'].mean()
# Out:
# 6.284634387351787

# %% [markdown]
# # calculate median Age

# %%
#calculate the median of 'AGE'
df1['AGE'].median()
# Out:
# 77.5

# %% [markdown]
# # calculate average (mean) distances to five Boston employment centres

# %%
#calculate the mean of 'DIS'
df1['DIS'].mean()
# Out:
# 3.795042687747034

# %% [markdown]
# # calculate the percentage of houses with low price (< $20,000)

# %%
# Create a Pandas series and compare it with 20
low_price=df1['PRICE']<20
print(low_price)
#convert price into percentage by multiplying with 100
pcnt=low_price.mean()*100
print("\nPercentage of house with <20,000 price is: ",pcnt)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 501    False
# 502    False
# 503    False
# 504    False
# 505     True
# Name: PRICE, Length: 506, dtype: bool
#
# Percentage of house with <20,000 price is:  41.50197628458498

# %% [markdown]
# # Activity 6: Working woth the Adult Income Dataset (UCI)

# %% [markdown]
# 2.Read the Adault Income Dataset From Directory

# %%
#Read "adult_income_data.csv" file 
df=pd.read_csv("adult_income_data.csv")
df.head()
# Out:
#    39          State-gov   77516   Bachelors  13        Never-married  \
# 0  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 1  38            Private  215646     HS-grad   9             Divorced
# 2  53            Private  234721        11th   7   Married-civ-spouse
# 3  28            Private  338409   Bachelors  13   Married-civ-spouse
# 4  37            Private  284582     Masters  14   Married-civ-spouse
#
#          Adm-clerical   Not-in-family     Male  2174  0  40   United-States  \
# 0     Exec-managerial         Husband     Male     0  0  13   United-States
# 1   Handlers-cleaners   Not-in-family     Male     0  0  40   United-States
# 2   Handlers-cleaners         Husband     Male     0  0  40   United-States
# 3      Prof-specialty            Wife   Female     0  0  40            Cuba
# 4     Exec-managerial            Wife   Female     0  0  40   United-States
#
#     <=50K
# 0   <=50K
# 1   <=50K
# 2   <=50K
# 3   <=50K
# 4   <=50K

# %% [markdown]
# 3.Create a script that will read a text file line by line

# %%
#Read "adult_income_data.text" file from directory and create the script to read the text file
#defin name
names = []
with open ('adult_income_names.txt') as fd:
    for line in fd:
# extracts the first phrase which is the header name
        fd.readline()
        var=line.split(":")[0]
        names.append(var)
names
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country']

# %% [markdown]
# 4.Add a name of 'Income' for the response variable(last column) to the data set

# %%
names.append("Income")

# %%
df = pd.read_csv("adult_income_data.csv",names=names)
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship      sex  \
# 0        Never-married        Adm-clerical   Not-in-family     Male
# 1   Married-civ-spouse     Exec-managerial         Husband     Male
# 2             Divorced   Handlers-cleaners   Not-in-family     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  Income
# 0          2174             0              40   United-States   <=50K
# ...

# %% [markdown]
# 5.find the missing value

# %%
# find missing value for any row or column 
df_missing=pd.read_csv("adult_income_data.csv")
df_missing
# Out:
#        39          State-gov   77516    Bachelors  13        Never-married  \
# 0      50   Self-emp-not-inc   83311    Bachelors  13   Married-civ-spouse
# 1      38            Private  215646      HS-grad   9             Divorced
# 2      53            Private  234721         11th   7   Married-civ-spouse
# 3      28            Private  338409    Bachelors  13   Married-civ-spouse
# 4      37            Private  284582      Masters  14   Married-civ-spouse
# ...    ..                ...     ...          ...  ..                  ...
# 32555  27            Private  257302   Assoc-acdm  12   Married-civ-spouse
# 32556  40            Private  154374      HS-grad   9   Married-civ-spouse
# 32557  58            Private  151910      HS-grad   9              Widowed
# 32558  22            Private  201490      HS-grad   9        Never-married
# 32559  52       Self-emp-inc  287927      HS-grad   9   Married-civ-spouse
#
#              Adm-clerical   Not-in-family     Male   2174  0  40  \
# ...

# %%
#Use the isnull function on the dataframe and observe the result 
df_missing.isnull()
# Out:
#           39   State-gov  77516   Bachelors     13   Never-married  \
# 0      False       False  False       False  False           False
# 1      False       False  False       False  False           False
# 2      False       False  False       False  False           False
# 3      False       False  False       False  False           False
# 4      False       False  False       False  False           False
# ...      ...         ...    ...         ...    ...             ...
# 32555  False       False  False       False  False           False
# 32556  False       False  False       False  False           False
# 32557  False       False  False       False  False           False
# 32558  False       False  False       False  False           False
# 32559  False       False  False       False  False           False
#
#         Adm-clerical   Not-in-family   Male   2174      0     40  \
# 0              False           False  False  False  False  False
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# Income            0
# dtype: int64

# %% [markdown]
# No missing value

# %% [markdown]
# 6. Create DataFrame with only Age, Education, and Occupation by using subsetting

# %%
df_subset = df[['age','education','occupation']]
df_subset.head()
# Out:
#    age   education          occupation
# 0   39   Bachelors        Adm-clerical
# 1   50   Bachelors     Exec-managerial
# 2   38     HS-grad   Handlers-cleaners
# 3   53        11th   Handlers-cleaners
# 4   28   Bachelors      Prof-specialty

# %% [markdown]
# 7. Plot a histogram of age with a bin size of 20

# %%
df_subset['age'].hist(bins=20)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 8. Create a function to strip the whitespace characters

# %%
def strip_whitespace(s):
    return s.strip()

# %%
df_1 = pd.read_csv("adult_income_names.txt", sep="\n", header=None)
df_1
# Out:
#                                                     0
# 0                                    age: continuous.
# 1   workclass: Private, Self-emp-not-inc, Self-emp...
# 2                                 fnlwgt: continuous.
# 3   education: Bachelors, Some-college, 11th, HS-g...
# 4                          education-num: continuous.
# 5   marital-status: Married-civ-spouse, Divorced, ...
# 6   occupation: Tech-support, Craft-repair, Other-...
# 7   relationship: Wife, Own-child, Husband, Not-in...
# 8                                  sex: Female, Male.
# 9                           capital-gain: continuous.
# 10                          capital-loss: continuous.
# 11                        hours-per-week: continuous.
# 12  native-country: United-States, Cambodia, Engla...

# %% [markdown]
# 9. Use the 'apply' method to apply this function to all the columns with string values, create a new column, copy the values from this new column to the old column, and drop the new column.

# %%
df_subset.loc[:, ["occupation"]]
# Out:
#                occupation
# 0            Adm-clerical
# 1         Exec-managerial
# 2       Handlers-cleaners
# 3       Handlers-cleaners
# 4          Prof-specialty
# ...                   ...
# 32556        Tech-support
# 32557   Machine-op-inspct
# 32558        Adm-clerical
# 32559        Adm-clerical
# 32560     Exec-managerial
#
# [32561 rows x 1 columns]

# %%
# Create a new column'occupation_stripped' 
df_subset['occupation_stripped']=df['occupation'].apply(strip_whitespace)
# Copy the values from this new 'occupation_stripped' column to the old column, 
df_subset['occupation']=df_subset['occupation_stripped']
# Drop the new column'occupation_stripped' 
df_subset.drop(labels=['occupation_stripped'],axis=1,inplace=True)
# Out:
# C:\Users\Yousof\AppData\Local\Temp/ipykernel_12000/2990300292.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['occupation_stripped']=df['occupation'].apply(strip_whitespace)
# C:\Users\Yousof\AppData\Local\Temp/ipykernel_12000/2990300292.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_subset['occupation']=df_subset['occupation_stripped']
# C:\Users\Yousof\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:4901: SettingWithCopyWarning:
# ...

# %% [markdown]
# I got the sample warning message, which I can ignore.
# I would like to run the code and see the output.However,I will take it line by line in separate code blocks and print out the ersults.

# %%
# Create a new column'occupation_stripped' 
df_subset['occupation_stripped']=df['occupation'].apply(strip_whitespace)
print(df_subset)
# Out:
#        age    education         occupation occupation_stripped
# 0       39    Bachelors       Adm-clerical        Adm-clerical
# 1       50    Bachelors    Exec-managerial     Exec-managerial
# 2       38      HS-grad  Handlers-cleaners   Handlers-cleaners
# 3       53         11th  Handlers-cleaners   Handlers-cleaners
# 4       28    Bachelors     Prof-specialty      Prof-specialty
# ...    ...          ...                ...                 ...
# 32556   27   Assoc-acdm       Tech-support        Tech-support
# 32557   40      HS-grad  Machine-op-inspct   Machine-op-inspct
# 32558   58      HS-grad       Adm-clerical        Adm-clerical
# 32559   22      HS-grad       Adm-clerical        Adm-clerical
# 32560   52      HS-grad    Exec-managerial     Exec-managerial
#
# [32561 rows x 4 columns]
# C:\Users\Yousof\AppData\Local\Temp/ipykernel_12000/650110596.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# Copy the values from this new 'occupation_stripped' column to the old column,
df_subset['occupation']=df_subset['occupation_stripped']
print(df_subset)
# Out:
#        age    education         occupation occupation_stripped
# 0       39    Bachelors       Adm-clerical        Adm-clerical
# 1       50    Bachelors    Exec-managerial     Exec-managerial
# 2       38      HS-grad  Handlers-cleaners   Handlers-cleaners
# 3       53         11th  Handlers-cleaners   Handlers-cleaners
# 4       28    Bachelors     Prof-specialty      Prof-specialty
# ...    ...          ...                ...                 ...
# 32556   27   Assoc-acdm       Tech-support        Tech-support
# 32557   40      HS-grad  Machine-op-inspct   Machine-op-inspct
# 32558   58      HS-grad       Adm-clerical        Adm-clerical
# 32559   22      HS-grad       Adm-clerical        Adm-clerical
# 32560   52      HS-grad    Exec-managerial     Exec-managerial
#
# [32561 rows x 4 columns]
# C:\Users\Yousof\AppData\Local\Temp/ipykernel_12000/1771598803.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# Drop the new column'occupation_stripped' 
df_subset.drop(labels=['occupation_stripped'],axis=1,inplace=True)
print(df_subset.drop)
# Out:
# <bound method DataFrame.drop of        age    education         occupation
# 0       39    Bachelors       Adm-clerical
# 1       50    Bachelors    Exec-managerial
# 2       38      HS-grad  Handlers-cleaners
# 3       53         11th  Handlers-cleaners
# 4       28    Bachelors     Prof-specialty
# ...    ...          ...                ...
# 32556   27   Assoc-acdm       Tech-support
# 32557   40      HS-grad  Machine-op-inspct
# 32558   58      HS-grad       Adm-clerical
# 32559   22      HS-grad       Adm-clerical
# 32560   52      HS-grad    Exec-managerial
#
# [32561 rows x 3 columns]>
# C:\Users\Yousof\AppData\Roaming\Python\Python39\site-packages\pandas\core\frame.py:4901: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# 10. Find the number of people who are aged between 30 and 50

# %%
#filter the dataframe and join them by and (&)
df_filtered=df_subset[(df_subset['age']>=30) & (df_subset['age']<=50)]

# %%
df_filtered.head()
# Out:
#    age   education         occupation
# 0   39   Bachelors       Adm-clerical
# 1   50   Bachelors    Exec-managerial
# 2   38     HS-grad  Handlers-cleaners
# 5   37     Masters    Exec-managerial
# 6   49         9th      Other-service

# %% [markdown]
# 11.Group the records based on age and education to find how the mean age is disterbuted

# %%
df_subset.groupby(['age','education']).mean()
# Out:
# Empty DataFrame
# Columns: []
# ...

# %% [markdown]
# 12. Group  by occupation and show the summary statistics of age. Find which profession has the oldest workers on avarage and which profession has its largest share of the workforce the 17th percentile

# %%
# Group by occupation and summary statistics of age
df_subset.groupby('occupation').describe()['age']
# Out:
#                     count       mean        std   min   25%   50%   75%   max
# occupation
# ?                  1843.0  40.882800  20.336350  17.0  21.0  35.0  61.0  90.0
# Adm-clerical       3770.0  36.964456  13.362998  17.0  26.0  35.0  46.0  90.0
# Armed-Forces          9.0  30.222222   8.089774  23.0  24.0  29.0  34.0  46.0
# Craft-repair       4099.0  39.031471  11.606436  17.0  30.0  38.0  47.0  90.0
# Exec-managerial    4066.0  42.169208  11.974548  17.0  33.0  41.0  50.0  90.0
# Farming-fishing     994.0  41.211268  15.070283  17.0  29.0  39.0  52.0  90.0
# Handlers-cleaners  1370.0  32.165693  12.372635  17.0  23.0  29.0  39.0  90.0
# Machine-op-inspct  2002.0  37.715285  12.068266  17.0  28.0  36.0  46.0  90.0
# Other-service      3295.0  34.949621  14.521508  17.0  22.0  32.0  45.0  90.0
# Priv-house-serv     149.0  41.724832  18.633688  17.0  24.0  40.0  57.0  81.0
# Prof-specialty     4140.0  40.517633  12.016676  17.0  31.0  40.0  48.0  90.0
# ...

# %% [markdown]
# 13. Use subset and groupby to find outliers.

# %%
# Groupby'occupation' to find the outliers
occupation_stats= df_subset.groupby('occupation').describe()['age']
#This function selects the min in each column and rows and highlights it in Red color to find out the outliers 
def highlight_min(s):    
    is_min = s == s.min()
    return ['background-color: Red' if v else '' for v in is_min]
occupation_stats.style.apply(highlight_min)
# Out:
# <style type="text/css">
# #T_70b05_row0_col3, #T_70b05_row0_col4, #T_70b05_row1_col3, #T_70b05_row2_col0, #T_70b05_row2_col1, #T_70b05_row2_col2, #T_70b05_row2_col5, #T_70b05_row2_col6, #T_70b05_row2_col7, #T_70b05_row3_col3, #T_70b05_row4_col3, #T_70b05_row5_col3, #T_70b05_row6_col3, #T_70b05_row6_col5, #T_70b05_row7_col3, #T_70b05_row8_col3, #T_70b05_row9_col3, #T_70b05_row10_col3, #T_70b05_row11_col3, #T_70b05_row12_col3, #T_70b05_row13_col3, #T_70b05_row14_col3 {
#   background-color: Red;
# }
# </style>
# <table id="T_70b05_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
# ...

# %% [markdown]
# 14. Plot the values on a bar chart

# %%
plt.figure(figsize=(15,8))
plt.barh(y=occupation_stats.index,width=occupation_stats['count'])
plt.yticks(fontsize=13)
plt.show()

# %% [markdown]
# 15. Merge the data using common key

# %%
#DataFrame 1 associated with 'age','sex','occupation'
df_1 = df[['age','sex','occupation']].sample(5,random_state=101)

# %%
df_1.head()
# Out:
#        age      sex          occupation
# 22357   51   Female   Machine-op-inspct
# 26009   19     Male               Sales
# 20734   40     Male     Exec-managerial
# 17695   17     Male   Handlers-cleaners
# 27908   61     Male        Craft-repair

# %%
#DataFrame 2 associated with 'occupation','relationship','education'
df_2 = df[['occupation','relationship','education']].sample(5,random_state=101)

# %%
df_2.head()
# Out:
#                occupation relationship education
# 22357   Machine-op-inspct         Wife   HS-grad
# 26009               Sales    Own-child      11th
# 20734     Exec-managerial      Husband   HS-grad
# 17695   Handlers-cleaners    Own-child      10th
# 27908        Craft-repair      Husband   7th-8th

# %%
# Join the two tables by inner join and drop the duplicates
df_merged = pd.merge(df_1,df_2,on='occupation',how='inner').drop_duplicates()

# %%
df_merged
# Out:
#    age      sex          occupation relationship education
# 0   51   Female   Machine-op-inspct         Wife   HS-grad
# 1   19     Male               Sales    Own-child      11th
# 2   40     Male     Exec-managerial      Husband   HS-grad
# 3   17     Male   Handlers-cleaners    Own-child      10th
# 4   61     Male        Craft-repair      Husband   7th-8th

# %% [markdown]
# # 3. Create a series and practice basic arithmetic steps

# %%
#Create a series 1 
#a. Series 1 = 7.3, -2.5, 3.4, 1.5
#i. Index = ‘a’, ‘c’, ‘d’, ‘e’
lables = ['a', 'c', 'd', 'e']
my_data = [7.3, -2.5, 3.4, 1.5]
array_1 = np.array(my_data)
series_1=pd.Series(array_1, lables)
print(series_1)
# Out:
# a    7.3
# c   -2.5
# d    3.4
# e    1.5
# dtype: float64

# %%
#Create a series 2
#b. Series 2 = -2.1, 3.6, -1.5, 4, 3.1
#i. Index = ‘a’, ‘c’, ‘e’, ‘f’, ‘g’
lables = ['a', 'c','e','f', 'g']
my_data = [-2.1, 3.6, -1.5, 4, 3.1]
array_2 = np.array(my_data)
series_2=pd.Series(array_2, lables)
print(series_2)
# Out:
# a   -2.1
# c    3.6
# e   -1.5
# f    4.0
# g    3.1
# dtype: float64

# %% [markdown]
# c. Add Series 1 and Series 2 together and print the results

# %%
#Add Series 1 and Series 2 together and print the results
add=series_1+series_2
print(add)
# Out:
# a    5.2
# c    1.1
# d    NaN
# e    0.0
# f    NaN
# g    NaN
# dtype: float64

# %% [markdown]
# d. Subtract Series 1 from Series 2 and print the results

# %%
#Subtract Series 1 from Series 2 and print the results
Subtract=series_1/series_2
print(Subtract)
# Out:
# a   -3.476190
# c   -0.694444
# d         NaN
# e   -1.000000
# f         NaN
# g         NaN
# dtype: float64
